# %% [markdown]
# # Pose data validation plots

# %% [markdown]
# Plot reconstruction errors from DeepLabCut (not present in NWB files) and contralateral wrist trajectories during move events to validate pose data and event metadata quality.

# %%
# %pip install natsort
# %pip install seaborn
# %pip install nilearn
# %pip install git+https://github.com/dandi/dandi-cli.git
# %pip install git+https://github.com/catalystneuro/brunton-lab-to-nwb.git

# %%
import matplotlib.pyplot as plt
from plot_utils import plot_dlc_recon_errs, plot_wrist_trajs

# %% [markdown]
# ## Generate pose validation plots

# %%
fig, ax = plt.subplots(1, 2, figsize=(7, 3), dpi=150)

# Plot DLC reconstruction errors
plot_dlc_recon_errs(fig, ax[0])

# Plot contralateral wrist trajectories (takes a few minutes to run)
plot_wrist_trajs(fig, ax[1])

plt.show()
# Out:
# /home/stepeter/AJILE/ajile12-nwb-data/figs/plot_utils.py:558: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sbj, rotation=45)

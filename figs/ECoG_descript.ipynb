# %% [markdown]
# # ECoG data descriptor plots

# %% [markdown]
# Plots ECoG electrode positions and the number of identified noisy electrodes for each participant.

# %%
# %pip install natsort
# %pip install seaborn
# %pip install nilearn
# %pip install dandi
# %pip install git+https://github.com/catalystneuro/brunton-lab-to-nwb.git

# %%
from plot_utils import load_data_characteristics, plot_ecog_descript

# %% [markdown]
# ## Generate plots

# %%
dat_chact = load_data_characteristics()
n_elecs_good, n_elecs_tot = dat_chact[-2], dat_chact[-1]
part_ids = dat_chact[-3]

plot_ecog_descript(n_elecs_tot, n_elecs_good, part_ids)
# Out:
# /home/stepeter/AJILE/ajile12-nwb-data/figs/plot_utils.py:243: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[-1].set_xticklabels(part_ids, rotation=45)

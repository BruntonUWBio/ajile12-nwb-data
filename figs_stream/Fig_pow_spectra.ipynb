# %%
# %pip install natsort
# %pip install seaborn
# %pip install nilearn
# %pip install dandi
# %pip install git+https://github.com/catalystneuro/brunton-lab-to-nwb.git

# %%
from plot_utils import plot_ecog_pow, load_data_characteristics, plot_ecog_descript

# %% [markdown]
# ## Set parameters

# %%
rois_plt = ['Precentral','Postcentral','Temporal_Mid','Temporal_Inf']
sbplt_titles = ['Precentral\nGyrus','Postcentral\nGyrus',
                'Middle Temporal\nGyrus','Inferior Temporal\nGyrus']
freq_range = [3, 125]
lp = '/data1/users/stepeter/mvmt_init/data_spec/'

# %% [markdown]
# ## Plot ECoG electrode locations

# %%
dat_chact = load_data_characteristics()
n_elecs_good, n_elecs_tot = dat_chact[-2], dat_chact[-1]
part_ids = dat_chact[-3]

fig = plot_ecog_descript(n_elecs_tot, n_elecs_good, part_ids, nrows=2)

# %% [markdown]
# ## Generate projected power plots

# %%
plot_ecog_pow(lp, rois_plt, freq_range, sbplt_titles, part_id='P01')
